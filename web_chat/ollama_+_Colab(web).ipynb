# %% [markdown]
# # Colab + Ollama
# ---
# ## Install ollama on colab and use cloud gpu to run any Open source **L**arge **L**anguage **M**odel
# ---
# ### steps to follow before installing ollama
# - change connection type from CPU to T4 GPU

# %%
# @title
# !apt-get install zstd
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (502 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ## Install ollama

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# Before running next cell open terminal from bottom left of window and run `ollama serve &` in terminal and press `Ctrl` + `C`.
# > It will run ollama server in background, we will need it's service to Download ,Install and Run LLM's

# %% [markdown]
# ---
# run this command
# `ollama pull <model-name>`  to install LLM or run `ollama run <model-name>` to install and run  \
#  Replace `<model-name>` with llm name you want to install, I will be installing Gemma 3
# ### List of llms from ollama GitHub
#
# ## Model library
#
# Ollama supports a list of models available on [ollama.com/library](https://ollama.com/library "ollama model library")
#
# Here are some example models that can be downloaded:
#
# | Model              | Parameters | Size  | Download                         |
# | ------------------ | ---------- | ----- | -------------------------------- |
# | Gemma 3            | 1B         | 815MB | `ollama run gemma3:1b`           |
# | Gemma 3            | 4B         | 3.3GB | `ollama run gemma3`              |
# | Gemma 3            | 12B        | 8.1GB | `ollama run gemma3:12b`          |
# | Gemma 3            | 27B        | 17GB  | `ollama run gemma3:27b`          |
# | QwQ                | 32B        | 20GB  | `ollama run qwq`                 |
# | DeepSeek-R1        | 7B         | 4.7GB | `ollama run deepseek-r1`         |
# | DeepSeek-R1        | 671B       | 404GB | `ollama run deepseek-r1:671b`    |
# | Llama 4            | 109B       | 67GB  | `ollama run llama4:scout`        |
# | Llama 4            | 400B       | 245GB | `ollama run llama4:maverick`     |
# | Llama 3.3          | 70B        | 43GB  | `ollama run llama3.3`            |
# | Llama 3.2          | 3B         | 2.0GB | `ollama run llama3.2`            |
# | Llama 3.2          | 1B         | 1.3GB | `ollama run llama3.2:1b`         |
# | Llama 3.2 Vision   | 11B        | 7.9GB | `ollama run llama3.2-vision`     |
# | Llama 3.2 Vision   | 90B        | 55GB  | `ollama run llama3.2-vision:90b` |
# | Llama 3.1          | 8B         | 4.7GB | `ollama run llama3.1`            |
# | Llama 3.1          | 405B       | 231GB | `ollama run llama3.1:405b`       |
# | Phi 4              | 14B        | 9.1GB | `ollama run phi4`                |
# | Phi 4 Mini         | 3.8B       | 2.5GB | `ollama run phi4-mini`           |
# | Mistral            | 7B         | 4.1GB | `ollama run mistral`             |
# | Moondream 2        | 1.4B       | 829MB | `ollama run moondream`           |
# | Neural Chat        | 7B         | 4.1GB | `ollama run neural-chat`         |
# | Starling           | 7B         | 4.1GB | `ollama run starling-lm`         |
# | Code Llama         | 7B         | 3.8GB | `ollama run codellama`           |
# | Llama 2 Uncensored | 7B         | 3.8GB | `ollama run llama2-uncensored`   |
# | LLaVA              | 7B         | 4.5GB | `ollama run llava`               |
# | Granite-3.3        | 8B         | 4.9GB | `ollama run granite3.3`          |
#
# > [!NOTE]
# > You should have at least 8 GB of RAM available to run the 7B models, 16 GB to run the 13B models, and 32 GB to run the 33B models.

# %%
# !ollama pull gemma3
# !ollama pull gemma3:1b
# !ollama pull gpt-oss:20b

# %%
# install ollama in python
! pip install ollama requests

# %%
from ollama import chat

# %%
def ask_llm(prompt, history=None,model='gemma3'):
    print('calling LLM')
    messages = []
    if history:
        for u, b in history:
            messages.append({"role": "user", "content": u})
            messages.append({"role": "assistant", "content": b})
    messages.append({"role": "user", "content": prompt})

    response = chat(
        model=model,
        messages=messages,
        stream=False
    )
    print("done colling")
    return response["message"]["content"]

# %%
ask_llm("who is pikachu? maximum 20 words")
# Out:
# calling LLM
# done colling
# 'Pikachu is a beloved electric mouse Pokémon, instantly recognizable for its yellow fur and iconic cheeks!'

# %%
def start_chat(model='gemma3'):
  history = []
  while True:
    prompt = input("\nask-> ")
    if prompt in ('/bye', 'exit'): break
    response = ask_llm(prompt=prompt,history=history,model=model)
    print("\n",response)
    history.append((prompt,response))
  return history

# %%
# start_chat(model='gemma3:1b')

# %%
# !pip install -q flask

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64

# %% [markdown]
# ## Run following command in terminal
# `./cloudflared-linux-amd64 tunnel --url http://localhost:1211`\
# it will give url, copy url and open it in new browser tab
#
# > [!]example
#
# 2026-01-23T11:49:21Z INF +--------------------------------------------------------------------------------------------+\
# 2026-01-23T11:49:21Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):|\
# 2026-01-23T11:49:21Z INF |  https://example.trycloudflare.com| \
# 2026-01-23T11:49:21Z INF +--------------------------------------------------------------------------------------------+

# %%
from flask import Flask, request, render_template_string

# %%
HTML = """
<!doctype html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Simple Chat</title>

<style>
    * {
        box-sizing: border-box;
    }

    body {
        margin: 0;
        font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Arial, sans-serif;
        background: linear-gradient(135deg, #1a1d29 0%, #2b2d31 100%);
        color: #e4e6eb;
        height: 100vh;
        display: flex;
        flex-direction: column;
    }

    header {
        padding: 16px 20px;
        background: rgba(30, 31, 34, 0.95);
        backdrop-filter: blur(10px);
        font-weight: 600;
        font-size: 1.1em;
        border-bottom: 1px solid rgba(255, 255, 255, 0.06);
        box-shadow: 0 2px 8px rgba(0, 0, 0, 0.2);
        letter-spacing: 0.3px;
    }

    .chat-container {
        flex: 1;
        padding: 20px;
        overflow-y: auto;
        scroll-behavior: smooth;
    }

    .chat-container::-webkit-scrollbar {
        width: 8px;
    }

    .chat-container::-webkit-scrollbar-track {
        background: transparent;
    }

    .chat-container::-webkit-scrollbar-thumb {
        background: rgba(255, 255, 255, 0.1);
        border-radius: 4px;
    }

    .chat-container::-webkit-scrollbar-thumb:hover {
        background: rgba(255, 255, 255, 0.15);
    }

    .message {
        display: flex;
        margin-bottom: 8px;
        animation: slideIn 0.3s ease-out;
    }

    @keyframes slideIn {
        from {
            opacity: 0;
            transform: translateY(10px);
        }
        to {
            opacity: 1;
            transform: translateY(0);
        }
    }

    .avatar {
        width: 40px;
        height: 40px;
        border-radius: 50%;
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        display: flex;
        align-items: center;
        justify-content: center;
        font-weight: 600;
        margin-right: 14px;
        flex-shrink: 0;
        font-size: 0.9em;
        box-shadow: 0 2px 8px rgba(102, 126, 234, 0.3);
    }

    .avatar.bot {
        background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%);
        box-shadow: 0 2px 8px rgba(56, 239, 125, 0.3);
    }

    .content {
        background: rgba(49, 51, 56, 0.6);
        backdrop-filter: blur(10px);
        padding: 12px 16px;
        border-radius: 12px;
        max-width: 70%;
        line-height: 1.5;
        border: 1px solid rgba(255, 255, 255, 0.05);
        box-shadow: 0 2px 8px rgba(0, 0, 0, 0.2);
    }

    .content p {
        margin: 0 0 8px 0;
    }

    .content p:last-child {
        margin-bottom: 0;
    }

    .content code {
        background: rgba(0, 0, 0, 0.3);
        padding: 2px 6px;
        border-radius: 4px;
        font-family: 'Courier New', monospace;
        font-size: 0.9em;
    }

    .content pre {
        background: rgba(0, 0, 0, 0.3);
        padding: 12px;
        border-radius: 6px;
        overflow-x: auto;
        margin: 8px 0;
    }

    .content pre code {
        background: none;
        padding: 0;
    }

    .content strong {
        font-weight: 600;
        color: #fff;
    }

    .content em {
        font-style: italic;
        color: #d1d3d6;
    }

    .content ul, .content ol {
        margin: 8px 0;
        padding-left: 24px;
    }

    .content li {
        margin: 4px 0;
    }

    .username {
        font-size: 0.85em;
        font-weight: 600;
        margin-bottom: 2px;
        color: #b9bbbe;
        text-transform: uppercase;
        letter-spacing: 0.5px;
    }

    form {
        display: flex;
        padding: 16px 20px;
        background: rgba(30, 31, 34, 0.95);
        backdrop-filter: blur(10px);
        border-top: 1px solid rgba(255, 255, 255, 0.06);
        gap: 12px;
    }

    input[name="prompt"] {
        flex: 1;
        padding: 12px 16px;
        border-radius: 24px;
        border: 1px solid rgba(255, 255, 255, 0.08);
        outline: none;
        background: rgba(49, 51, 56, 0.6);
        color: #e4e6eb;
        font-size: 0.95em;
        transition: all 0.2s ease;
    }

    input[name="prompt"]:focus {
        border-color: rgba(102, 126, 234, 0.5);
        background: rgba(49, 51, 56, 0.8);
        box-shadow: 0 0 0 3px rgba(102, 126, 234, 0.1);
    }

    input[name="prompt"]::placeholder {
        color: #72767d;
    }

    input[type="submit"] {
        padding: 12px 24px;
        border-radius: 24px;
        border: none;
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        color: white;
        font-weight: 600;
        cursor: pointer;
        transition: all 0.2s ease;
        box-shadow: 0 2px 8px rgba(102, 126, 234, 0.3);
    }

    input[type="submit"]:hover {
        transform: translateY(-1px);
        box-shadow: 0 4px 12px rgba(102, 126, 234, 0.4);
    }

    input[type="submit"]:active {
        transform: translateY(0);
    }

    /* Tablet responsiveness */
    @media (max-width: 768px) {
        header {
            padding: 14px 16px;
            font-size: 1em;
        }

        .chat-container {
            padding: 16px;
        }

        .content {
            max-width: 80%;
        }

        .avatar {
            width: 36px;
            height: 36px;
            margin-right: 12px;
            font-size: 0.85em;
        }

        form {
            padding: 14px 16px;
            gap: 10px;
        }

        input[type="submit"] {
            padding: 12px 20px;
        }
    }

    /* Mobile responsiveness */
    @media (max-width: 480px) {
        header {
            padding: 12px 14px;
            font-size: 0.95em;
        }

        .chat-container {
            padding: 12px;
        }

        .content {
            max-width: 85%;
            padding: 10px 14px;
            font-size: 0.95em;
        }

        .avatar {
            width: 32px;
            height: 32px;
            margin-right: 10px;
            font-size: 0.8em;
        }

        .username {
            font-size: 0.8em;
        }

        form {
            padding: 12px;
            gap: 8px;
        }

        input[name="prompt"] {
            padding: 10px 14px;
            font-size: 0.9em;
            border-radius: 20px;
        }

        input[type="submit"] {
            padding: 10px 18px;
            font-size: 0.9em;
            border-radius: 20px;
        }

        .content code {
            font-size: 0.85em;
        }

        .content pre {
            padding: 10px;
            font-size: 0.85em;
        }
    }

    /* Very small screens */
    @media (max-width: 360px) {
        .content {
            max-width: 90%;
        }

        input[type="submit"] {
            padding: 10px 14px;
        }
    }
</style>
</head>

<body>

<script src="https://cdnjs.cloudflare.com/ajax/libs/marked/11.1.1/marked.min.js"></script>
<script>
    marked.setOptions({
        breaks: true,
        gfm: true
    });
</script>

<header>💬 web chat</header>

<div class="chat-container">
    {% for user, bot in history %}
        <div class="message">
            <div class="avatar">U</div>
            <div class="content">
                <div class="username">You</div>
                {{ user }}
            </div>
        </div>

        <div class="message">
            <div class="avatar bot">B</div>
            <div class="content">
                <div class="username">Bot</div>
                <div class="bot-message"></div>
            </div>
        </div>
    {% endfor %}
</div>

<script>
    // Render markdown for bot messages
    document.addEventListener('DOMContentLoaded', function() {
        const botMessages = document.querySelectorAll('.bot-message');
        const rawMessages = [
            {% for user, bot in history %}
                {{ bot | tojson }},
            {% endfor %}
        ];

        botMessages.forEach((el, i) => {
            el.innerHTML = marked.parse(rawMessages[i]);
        });
    });
</script>

<form method="post">
    <input name="prompt" autofocus placeholder="Type your message…">
    <input type="submit" value="Send">
</form>

</body>
</html>
"""

# %%
app = Flask(__name__)

# %%
history = []

# %%
system_prompt = input('Enter system prompt: ')
if system_prompt:
  history.append((system_prompt,'ok'))
# Out:
# Enter system prompt: You are Doraemon, the blue robotic cat from the 22nd century.  Personality: - Warm, friendly, playful, and slightly comedic - Patient and caring, especially when the user is confused or stressed - Occasionally scolds gently, but always supportive - Speaks in a cheerful, simple, and encouraging tone  Behavior: - Treat the user as Nobita (even if you don’t name them directly every time) - Explain things clearly and simply, step by step - When appropriate, compare solutions to using a futuristic gadget from your pocket - Encourage learning, effort, and kindness rather than shortcuts  Style: - Use light humor and optimism - Avoid sarcasm or harsh criticism - Emojis are allowed but used sparingly 😊 - Never break character or mention being an AI or language model  Rules: - Be helpful first, playful second - If the user asks something unsafe or harmful, gently refuse and redirect like a caring guardian - Always aim to teach, not just answer  You are Doraemon. Act accord
# ...

# %%
@app.route("/", methods=["GET", "POST"])
def chat_llm():
    global history
    model = "gemma3"

    if request.method == "POST":
        prompt = request.form["prompt"]

        if prompt not in ("/bye", "exit"):
            response = ask_llm(prompt, history, model)
            print(history)
            history.append((prompt, response))

    return render_template_string(HTML, history=history)

# %%
# Run server
if __name__ == "__main__":
    app.run(host="0.0.0.0", port=1211,debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:1211
#  * Running on http://172.28.0.12:1211
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2026 11:27:08] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2026 11:27:44] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2026 11:27:46] "GET /favicon.ico HTTP/1.1" 404 -
# calling LLM
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2026 11:28:19] "POST / HTTP/1.1" 200 -
# done colling
# ...
